# %%
import anthropic
from anthropic.types.message_create_params import MessageCreateParamsNonStreaming
from anthropic.types.messages.batch_create_params import Request

import json
import math
import pandas as pd

import functions.prompts as prompts

client = anthropic.Anthropic()

# %%
import numpy as np

df = pd.read_csv("papers.csv")
# df.iloc[np.r_[0:4, -4:0]]
df.head()
# Out:
#     id                                               file  \
# 0  1_0                     1. Econometrica/ecta200736.pdf
# 1  1_1                     1. Econometrica/ecta200731.pdf
# 2  1_2                     1. Econometrica/ecta200725.pdf
# 3  1_3                     1. Econometrica/ecta200741.pdf
# 4  1_4  1. Econometrica/Econometrica - 2025 - Berger -...
#
#                                           name       journal  \
# 0   The Political Economy of Zero-Sum Thinking  Econometrica
# 1  Social Media and Collective Action in China  Econometrica
# 2                          Ambiguous Contracts  Econometrica
# 3                  PERSUASION MEETS DELEGATION  Econometrica
# 4       Minimum Wages, Efficiency, and Welfare  Econometrica
#
#                                              authors  \
# 0         S. Nageeb Ali; Maximilian Mihm; Lucas Siga
# 1                Bei Qin; David Strömberg; Yanhui Wu
# 2  Paul Dütting; Michal Feldman; Daniel Peretz; L...
# 3               Anton Kolotilin; Andriy Zapechelnyuk
# 4        David Berger; Kyle Herkenhoff; Simon Mongey
#
#                                         affiliations  len-original  len-anond
# 0  Department of Economics, Pennsylvania State Un...       16496.0    15956.0
# 1  Bei Qin: Department of Accountancy, Economics ...       18206.0    17419.0
# 2  Google Research; School of Computer Science, T...       11830.0    11448.0
# 3  Anton Kolotilin: School of Economics, UNSW Bus...       15756.0    15075.0
# 4  Economics Department, Duke University; Departm...       18607.0    16735.0

# %%
def req(id, text, top5=True):
    return Request(
        custom_id=id,
        params=MessageCreateParamsNonStreaming(
            model="claude-3-5-haiku-20241022",
            max_tokens=1024,
            system=f"{prompts.top5() if top5 else prompts.analysis()}\nPlease respond in valid JSON format that matches this schema: {str(prompts.Top5Model.model_json_schema() if top5 else prompts.AnalysisModel.model_json_schema())}. **IMPORTANT**: ONLY RESPOND WITH AN JSON OBJECT CONTAINING SCORES ACCORDING TO THE ABOVE SCHEMA. THE RESPONSE MUST END WITH A CURLY BRACKET. DO NOT ADD ANALYSIS OR EXPLANATION.",
            messages=[{
                "role": "user",
                "content": text
            }, {
                "role": "assistant",
                "content": "{"
            }]
        )
    )
    
def batch(text, id):
    return [    *[ req(f"{id}Z{i}Qtop5", text) for i in range(3) ],
                *[ req(f"{id}Z{i}Qanalysis", text, top5=False) for i in range(3) ] ]

# %%
full_req = {}
divider = 5
for i in range(divider):
    full_req[f'batch-{i}'] = []

# .iloc[np.r_[0:4, -4:0]]

for index, row in df.iterrows():
    file_index = math.floor(index / (len(df) / divider))
    with open(f'output/{row["id"]}.txt', 'r') as f:
        text = f.read()
        paper = f"PAPER TITLE: {row['name']}\n\nPAPER TEXT: {text}"
        full_req[f"batch-{file_index}"] += batch(paper, row["id"])

# %%
for i in range(divider):
    print(len(full_req[f'batch-{i}']))
# Out:
# 1320
# 1320
# 1320
# 1320
# 1320

# %%
full_req[f'batch-{i}'][0]
# Out:
# {'custom_id': '89_0Z0Qtop5',
#  'params': {'model': 'claude-3-5-haiku-20241022',
#   'max_tokens': 1024,
#   'system': "In your capacity as a reviewer for one of the most prestigious and highly selective top-5 economics journals (such as Econometrica, Journal of Political Economy, or The Quarterly Journal of Economics), please determine whether you would recommend this submission for publication using the following 7-point scale: 1 = Definite Reject: Fatal flaws in theory/methodology, insufficient contribution, or serious validity concerns that make the paper unsuitable for the journal, 2 = Reject with Option to Resubmit: Significant issues with theory, methodology, or contribution, but potentially salvageable with major revisions and fresh review, 3 = Major Revision: Substantial changes needed to theory, empirics, or exposition, but the core contribution is promising enough to warrant another round, 4 = Minor Revision: Generally strong paper with few small changes needed in exposition, robustness checks, or literature discussion, 5 = Very Minor Revision: Excellent contribution needing only technical corrections or minor clarifications, 6 = Accept As Is: Exceptional contribution ready for immediate publication\nPlease respond in valid JSON format that matches this schema: {'properties': {'score': {'title': 'Score', 'type': 'integer'}}, 'required': ['score'], 'title': 'Top5Model', 'type': 'object'}. **IMPORTANT**: ONLY RESPOND WITH AN JSON OBJECT CONTAINING SCORES ACCORDING TO THE ABOVE SCHEMA. THE RESPONSE MUST END WITH A CURLY BRACKET. DO NOT ADD ANALYSIS OR EXPLANATION.",
#   'messages': [{'role': 'user',
#     'content': 'PAPER TITLE: The Sovereign Debt Crisis in Sri Lanka: Anatomy and Policy Options\n\nPAPER TEXT: The Sovereign Debt Crisis in Sri Lanka: Anatomy and Policy Options*      Abstract During the COVID-19 pandemic,there was a dramatic increase in national debt levels across the world, with reported cases of downgrading sovereign debt ratings and difficulty of fulfilling debt obligations (“debt distress”),heavily concentrated in low- and middle-income countries.In this context,the unfold- ing sovereign debt crisis in Sri Lanka has attracted worldwide attention as the canary in the coal mine for what could become a global “development”crisis.This paper examines the Sri Lankan crisis encompass- ing both the sources of vulnerability to the COVD-19 shock,and stabilization and structural adjustment reforms after the debt default,with emphasis on the systemic “solvency”challenge of dealing with the massive debt overhang evolved over the previous two decades.The prime focus of the Extended Fund Facility (EFF) program that Sri Lanka signed with the IMF in March 2023 is on economic stabilization through fiscal consolidation.This paper makes a strong case for combining economic stabilization with coherent structural adjustment policies to redress the long-standing antitradable bias in the incentive structure that underpinned vulnerability of the economy to external shocks. 1. Introduction The COVID-19 pandemic has brought the subject of sovereign debt management to the forefront in the international development policy debate. While the pandemic has resulted in a dramatic increase in national debt levels across the entire globe, the reported cases of downgrading sovereign debt ratings and “debt distress”—difﬁculty of fulﬁlling debt obligations—are heavily concentrated in low- and middle-income countries (Kose et al. 2022; Rogoff 2022). Managing unsustainable sovereign debt to restore access to capital *\nmarkets is a vital policy priority for sustained and equitable economic recovery from the COVID-19 shock in these countries. The purpose of this paper is to contribute to the pandemic-propelled literature on sovereign debt crisis by undertaking an in-depth study of the experience of Sri Lanka, the second country to default on sovereign debt after Zambia in the COVID-19 era. Sri Lanka entered the pandemic with a huge debt overhang built up over the previous two decades. Some signiﬁcant policy initiatives of a new government that came into power in November 2019, which were inconsistent with the needed reform priorities of a country with an elevated level of public debt, added to the debt distress. The debt distress wors- ened when the government pursued a “muddling through” approach that was not con- gruent with the immediate impact of the pandemic on the balance of payments. When the government eventually went to the IMF in April 2022 after defaulting on foreign debt, the crisis-propelled sociopolitical instability had further complicated the process of debt re- structuring and negotiating a stabilization and structural adjustment program. The unfold- ing crisis in Sri Lanka has attracted international attention as a “warning sign” for policy strains faced by “countries with high debt levels and limited policy space” (Georgieva 2022) and as an illustrative case of how “postponing a reckoning through various piece- meal measures will make matters worse in the end” (Krueger 2022). Given that China is Sri Lanka’s largest bilateral creditor nation, the ongoing process of debit restricting is Sri Lanka and China’s refusal to participate on equal terms with the Western creditors has become a test case for the global ﬁnancial architecture in an age of superpower rivalry (The Economist 2023). The rest of the paper is structured in four sections. Section 2 examines the origins of the debt overhang and the mounting debt service burden that made the economy vulnerable to the ongoing crisis. Section 3 discusses the onset of the debt crisis, a ...
#    {'role': 'assistant', 'content': '{'}]}}

# %%
# KINDA DANGEROUS
# batches = []
# for i in range(divider):
#     print(f"Sending Batch {i}")
#     message_batch = client.messages.batches.create(
#         requests=full_req[f'batch-{i}'])
#     print(f"{i} {message_batch.id}")
#     batches.append(message_batch)

# print(batches)

# %%
import time

id = ""
def wait(id):
    results = client.messages.batches.retrieve(id).processing_status
    while results == "in_progress":
        stat = client.messages.batches.retrieve(id)
        print(stat.request_counts)
        results = stat.processing_status
        time.sleep(5)

wait(id)

# %%
batches = []
with open("dump/anthropic-batches.txt", 'r') as f:
    batches = f.read()
    batches = batches.split("\n")

# %%
def parse_r(r):
    id = r.custom_id
    validateModel = prompts.Top5Model if "top5" in id else prompts.AnalysisModel
    try:
        text = r.result.message.content[0].text
        text = "{" + text.split("}")[0] + "}"
        return {
            "id": id,
            "scores": validateModel.model_validate(json.loads(text)).model_dump()
        }
    except Exception as e:
        print(f"Error {e} - {"{" + r.result.message.content[0].text}")
        return {
            "id": id,
            "scores": None
        }

for b in batches:
    results = client.messages.batches.results(b)
    for r in results:
        if(r and r.result.type == 'succeeded'):
            try:
                with open('eval-output/anthropic-result.jsonl', 'a') as f:
                    f.write(json.dumps(parse_r(r)) + "\n")
            except Exception as e:
                print("ERROR! - " + str(e))

# %%
import pandas as pd

df = pd.read_csv("papers.csv")

f = open('eval-output/anthropic-result.jsonl', 'r')
file_response = f.read()
f.close()

for line in file_response.split("\n")[:-1]:
    l = json.loads(line)
    id = l['id'].split("Z")[0]
    no, typ = l['id'].split("Z")[1].split("Q")
    
    idx = df.index[df['id'] == id].tolist()[0]
    
    # content = l['response']['body']['choices'][0]['message']['content']
    
    metrics = ['score'] if typ == "top5" else ['originality', 'rigor', 'scope', 'impact', 'written_by_ai']
    validateModel = prompts.Top5Model if typ == "top5" else prompts.AnalysisModel

    for i, metric in enumerate(metrics):
        column_name = f"anthropic-{metric}-{int(no)+1}"
        
        if column_name not in df.columns:
            df[column_name] = None

        o = validateModel.model_validate(l['scores'])
        df.loc[idx, column_name] = o.__dict__[metric]

# %%
df['rank'] = df['id'].apply(lambda x: x.split("_")[0])
df
# Out:
#          id                                               file  \
# 0       1_0                     1. Econometrica/ecta200736.pdf
# 1       1_1                     1. Econometrica/ecta200731.pdf
# 2       1_2                     1. Econometrica/ecta200725.pdf
# 3       1_3                     1. Econometrica/ecta200741.pdf
# 4       1_4  1. Econometrica/Econometrica - 2025 - Berger -...
# ...     ...                                                ...
# 1095  P10_5  P10. Business and Econ Journal/the-impact-of-a...
# 1096  P10_6  P10. Business and Econ Journal/effect-of-workl...
# 1097  P10_7  P10. Business and Econ Journal/an-exploratory-...
# 1098  P10_8  P10. Business and Econ Journal/centre-peripher...
# 1099  P10_9  P10. Business and Econ Journal/the-impact-of-e...
#
#                                                    name  \
# 0            The Political Economy of Zero-Sum Thinking
# 1           Social Media and Collective Action in China
# 2                                   Ambiguous Contracts
# 3                           PERSUASION MEETS DELEGATION
# 4                Minimum Wages, Efficiency, and Welfare
# ...                                                 ...
# 1095  The Impact of Adoption of Agricultural Product...
# 1096  Effect of Work-Life Balance on Job Satisfactio...
# 1097  An Exploratory Study on the Viability of Corpo...
# 1098  Centre Periphery Relationship: An Analysis Abo...
# 1099  The Impact of Exchange Rate Fluctuations and M...
#
#                         journal  \
# 0                  Econometrica
# 1                  Econometrica
# 2                  Econometrica
# 3                  Econometrica
# 4                  Econometrica
# ...                         ...
# 1095  Business and Econ Journal
# 1096  Business and Econ Journal
# 1097  Business and Econ Journal
# 1098  Business and Econ Journal
# 1099  Business and Econ Journal
#
#                                                 authors  \
# 0            S. Nageeb Ali; Maximilian Mihm; Lucas Siga
# 1                   Bei Qin; David Strömberg; Yanhui Wu
# 2     Paul Dütting; Michal Feldman; Daniel Peretz; L...
# 3                  Anton Kolotilin; Andriy Zapechelnyuk
# 4           David Berger; Kyle Herkenhoff; Simon Mongey
# ...                                                 ...
# 1095                                       Getaye Gizaw
# 1096                        Fartun Ahmed Sheikh Mohamud
# 1097                                    Dr. Mesay Ayele
# 1098                                Jorge Italo de Lima
# 1099                                    Justice Ganawah
#
#                                            affiliations  len-original  \
# 0     Department of Economics, Pennsylvania State Un...       16496.0
# 1     Bei Qin: Department of Accountancy, Economics ...       18206.0
# 2     Google Research; School of Computer Science, T...       11830.0
# 3     Anton Kolotilin: School of Economics, UNSW Bus...       15756.0
# 4     Economics Department, Duke University; Departm...       18607.0
# ...                                                 ...           ...
# 1095  Getaye Gizaw, Department of Principal investig...        2951.0
# 1096  Fartun Ahmed Sheikh Mohamud, Department of Man...        4284.0
# 1097  Department of Management, Hawassa University, ...        9101.0
# 1098  Jorge Italo de Lima, Department of Textile and...        7311.0
# 1099  Justice Ganawah, Department of Economics and C...        3080.0
#
#       len-anond anthropic-score-1 anthropic-score-2  ... anthropic-rigor-2  \
# 0       15956.0                 4                 4  ...                 9
# 1       17419.0                 6                 6  ...                10
# 2       11448.0                 4                 4  ...                 9
# 3       15075.0                 4                 6  ...                 9
# 4       16735.0                 4                 5  ...                10
# ...         ...               ...               ...  ...               ...
# 1095     2807.0                 2                 3  ...                 8
# 1096     4046.0                 2                 2  ...                 7
# 1097     8039.0                 3                 2  ...                 8
# 1098     7117.0                 3                 3  ...                 8
# 1099     2964.0                 2                 2  ...                 7
#
#      anthropic-scope-2 anthropic-impact-2 anthropic-written_by_ai-2  \
# 0                    9                 10                         1
# 1                    9                 10                         1
# 2                    9                  8                         1
# 3                    9                  8                         1
# 4                    9                 10                         0
# ...                ...                ...                       ...
# 1095                 7                  7                         1
# 1096                 7                  6                         2
# 1097                 9                  8                         1
# 1098                 9                  8                         2
# 1099                 8                  7                         2
#
#      anthropic-originality-3 anthropic-rigor-3 anthropic-scope-3  \
# 0                          8                 9                 9
# 1                          9                10                 9
# 2                          8                 9                 9
# 3                          9                10                10
# 4                          8                 9                 9
# ...                      ...               ...               ...
# 1095                       6                 8                 7
# 1096                       6                 7                 8
# 1097                       7                 8                 9
# 1098                       7                 8                 9
# 1099                       6                 7                 8
#
#      anthropic-impact-3 anthropic-written_by_ai-3 rank
# 0                     9                         1    1
# 1                    10                         1    1
# 2                     8                         1    1
# 3                     9                         1    1
# 4                    10                         1    1
# ...                 ...                       ...  ...
# 1095                  7                         1  P10
# 1096                  7                         2  P10
# 1097                  8                         1  P10
# 1098                  8                         2  P10
# 1099                  7                         2  P10
#
# [1100 rows x 27 columns]

# %%
df.to_csv("result_a.csv", index=False)
