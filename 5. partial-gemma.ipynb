# %%
from openai import OpenAI
from dotenv import dotenv_values
import json
import math
import numpy as np
import pandas as pd
from concurrent.futures import ThreadPoolExecutor

import functions.prompts as prompts

config = dotenv_values(".env")

client = OpenAI(
    api_key=config['DEEPINFRA_TOKEN'],
    base_url="https://api.deepinfra.com/v1/openai",
)

# %%
df = pd.read_csv("dump/csv/papers.csv")
# df.iloc[np.r_[0:4, -4:0]]
df.head()
# Out:
#     id                                               file  \
# 0  1_0                     1. Econometrica/ecta200736.pdf
# 1  1_1                     1. Econometrica/ecta200731.pdf
# 2  1_2                     1. Econometrica/ecta200725.pdf
# 3  1_3                     1. Econometrica/ecta200741.pdf
# 4  1_4  1. Econometrica/Econometrica - 2025 - Berger -...
#
#                                           name       journal  \
# 0   The Political Economy of Zero-Sum Thinking  Econometrica
# 1  Social Media and Collective Action in China  Econometrica
# 2                          Ambiguous Contracts  Econometrica
# 3                  PERSUASION MEETS DELEGATION  Econometrica
# 4       Minimum Wages, Efficiency, and Welfare  Econometrica
#
#                                              authors  \
# 0         S. Nageeb Ali; Maximilian Mihm; Lucas Siga
# 1                Bei Qin; David Strömberg; Yanhui Wu
# 2  Paul Dütting; Michal Feldman; Daniel Peretz; L...
# 3               Anton Kolotilin; Andriy Zapechelnyuk
# 4        David Berger; Kyle Herkenhoff; Simon Mongey
#
#                                         affiliations  len-original  len-anond
# 0  Department of Economics, Pennsylvania State Un...       16496.0    15956.0
# 1  Bei Qin: Department of Accountancy, Economics ...       18206.0    17419.0
# 2  Google Research; School of Computer Science, T...       11830.0    11448.0
# 3  Anton Kolotilin: School of Economics, UNSW Bus...       15756.0    15075.0
# 4  Economics Department, Duke University; Departm...       18607.0    16735.0

# %%
def gen_body(text, top5=True, model="meta-llama/Llama-3.3-70B-Instruct-Turbo"):
    return {
            "model": model,
            "messages":[{
                    "role": "system",
                    "content": f"{prompts.top5() if top5 else prompts.analysis()}\nPlease respond in valid JSON format that matches this schema: {str(prompts.Top5Model.model_json_schema() if top5 else prompts.AnalysisModel.model_json_schema())}. **IMPORTANT**: ONLY RESPOND WITH AN JSON OBJECT CONTAINING SCORES ACCORDING TO THE ABOVE SCHEMA. THE RESPONSE MUST END WITH A CURLY BRACKET. DO NOT ADD ANALYSIS OR EXPLANATION."
                },
                {
                    "role": "user",
                    "content": text
                }, 
                {
                    "role": "assistant",
                    "content": "{"
                }],
        }

# %%
def partial(paper, no):
    l = len(paper.split())
    return " ".join(paper.split()[:math.ceil((l * no) / 100)])

def llm_paper(client, i, df, per):
    text = ""
    f = open(f"output/{df.iloc[i]['id']}.txt", "r")
    text = f.read()
    f.close()

    paper = f"PAPER TITLE: {df.iloc[i]['name']}\n\nPAPER TEXT: {partial(text, per)}"
    # print(per, paper)
    # gen_body(paper)
    
    model = "google/gemma-3-27b-it"
    # model = "meta-llama/Llama-3.3-70B-Instruct-Turbo"
    
    scores = [ client.chat.completions.create(**gen_body(paper, model=model)) for _ in range(3)]
    analysis = [ client.chat.completions.create(**gen_body(paper, top5=False, model=model)) for _ in range(3)]
    
    return {
        "scores": scores,
        "analysis": analysis
    }
    
def parse_r(r, id, typ):
    # id = r.custom_id
    validateModel = prompts.Top5Model if typ == "top5" else prompts.AnalysisModel
    try:
        # print(r)
        text = r.choices[0].message.content
        if(text.startswith("```json")):
            text = text.split("```json")[1].split("}")[0].replace("'", '"') + "}"
        else:
            text = "{" + text.split("}")[0].replace("'", '"') + "}"
        if(text.startswith("{{")):
            text = text[1:]
        return {
            "id": id,
            "scores": validateModel.model_validate(json.loads(text)).model_dump()
        }
    except Exception as e:
        print(f"Error {e} - {"{" + r.choices[0].message.content}")
        return {
            "id": id,
            "scores": None
        }

def parse_paper(rs):
    scores = [ parse_r(x, j, "top5") for j, x in enumerate(rs['scores']) ]
    analysis = [ parse_r(x, j, "analysis") for j, x in enumerate(rs['analysis']) ]
    return {
        "scores": scores,
        "analysis": analysis
    }

# %%
model_name = "gemma"

def update_df(df, i, no, score, typ, per):
    metrics = ['score'] if typ == "top5" else ['originality', 'rigor', 'scope', 'impact', 'written_by_ai']
    validateModel = prompts.Top5Model if typ == "top5" else prompts.AnalysisModel

    for _, metric in enumerate(metrics):
        column_name = f"{model_name}-{per}-{metric}-{int(no)+1}"
        
        if column_name not in df.columns:
            df[column_name] = None

        try:
            o = validateModel.model_validate(score)
            df.loc[i, column_name] = o.__dict__[metric]
        except:
            print(f"ERROR | Can't update the model in in {column_name}, skipping...")

# %%
def evaluate_paper(client, i, df):
    print(f"Evaluating {i} -> {df.iloc[i]['name']}")
    
    for per in [0.1, 1, 10, 50]:
        x = llm_paper(client, i, df, per)
        y = parse_paper(x)
    
        per_str = str(per).split(".")[0]
        
        for j, s in enumerate(y['scores']):
            update_df(df, i, j, s['scores'], "top5", per_str)
    
        for j, a in enumerate(y['analysis']):
            update_df(df, i, j, a['scores'], "analysis", per_str)
            
    print(f"Finish Evaluating {i} -> {df.iloc[i]['name']}")
    # update_df(df, i, 0, y['scores'][0]['scores'], "top5")
    # idx = df.index[df['id'] == id].tolist()[0]
    # content = l['response']['body']['choices'][0]['message']['content']
    
# evaluate_paper(client, 0, df)

# %%
# from concurrent.futures import ThreadPoolExecutor

# def evaluate_paper_per(client, i, df, per):
#     print(f"Evaluating {i} -> {df.iloc[i]['name']} with percentage {per}")
    
#     x = llm_paper(client, i, df, per)
#     y = parse_paper(x)

#     per_str = str(per).split(".")[0]
    
#     for j, s in enumerate(y['scores']):
#         update_df(df, i, j, s['scores'], "top5", per_str)

#     for j, a in enumerate(y['analysis']):
#         update_df(df, i, j, a['scores'], "analysis", per_str)
    
#     return per

# def evaluate_paper(client, i, df):
#     print(f"Starting evaluation for {i} -> {df.iloc[i]['name']}")
    
#     percentages = [0.1, 1, 10, 50]
    
#     with futures.ThreadPoolExecutor(max_workers=len(percentages)) as executor:
#         futures = {executor.submit(evaluate_paper_per, client, i, df, per): per for per in percentages}
        
#         for future in futures.as_completed(futures):
#             per = futures[future]
#             try:
#                 result = future.result()
#                 print(f"Completed {i} with percentage {result}")
#             except Exception as exc:
#                 print(f"Generated an exception for {i} with percentage {per}: {exc}")
    
#     print(f"Completed all evaluations for {i} -> {df.iloc[i]['name']}")

# %%
import math

chunk = 100
for i in range(0, len(df), chunk):
    print(f"PROCESSING CHUNK {(i // chunk) + 1} of {math.ceil(len(df) / chunk)}")
    with ThreadPoolExecutor(max_workers=200) as executor:
        results = list(executor.map(
            evaluate_paper, 
            [client] * chunk,
            [j for j in range(i, min(i+chunk, len(df)))],
            [df] * len(df["file"]),
        ))
        
    df.to_csv(f"{model_name}/{(i // chunk) + 1}.csv", index=False)
# Out:
# PROCESSING CHUNK 1 of 11
# Evaluating 0 -> The Political Economy of Zero-Sum Thinking
# Evaluating 1 -> Social Media and Collective Action in China
# Evaluating 2 -> Ambiguous Contracts
# Evaluating 3 -> PERSUASION MEETS DELEGATION
# Evaluating 4 -> Minimum Wages, Efficiency, and Welfare
# Evaluating 5 -> The Impacts of Managerial Autonomy on Firm Outcomes
# Evaluating 6 -> Sparse Network Asymptotics for Logistic Regression Under Possible Misspecification
# Evaluating 7 -> Seeding a Simple Contagion
# Evaluating 8 -> CAUTION AND REFERENCE EFFECTS
# Evaluating 9 -> HISTORY’S MASTERS: THE EFFECT OF EUROPEAN MONARCHS ON STATE PERFORMANCE
# Evaluating 10 -> Stories, Statistics, and Memory
# Evaluating 11 -> A Welfare Analysis of Tax Audits across the Income Distribution
# Evaluating 12 -> War Reparations, Structural Change, and Intergenerational Mobility
# Evaluating 13 -> THE DYNAMICS OF ABUSIVE RELATIONSHIPS
# Evaluating 14 -> Present Bias Amplifies the Household Balance-Sheet Channels of Macroeconomic Policy
# Evaluating 15 -> Overinference from Weak Signals and Underinference from Strong Signals
# Evaluating 16 -> EVOLUTION VS. CREATIONISM IN THE CLASSROOM: THE LASTING EFFECTS OF SCIENCE EDUC A TION
# Evaluating 17 -> THE LONG-RUN IMPACTS OF PUBLIC INDUSTRIAL INVESTMENT ON LOCAL DEVELOPMENT AND ECONOMIC MOBILITY: EVIDENCE FROM WORLD WAR II
# Evaluating 18 -> Believed Gender Differences in Social Preferences
# Evaluating 19 -> MANDATORY NOTICE OF LAYOFF, JOB SEARCH, AND EFFICIENCY
# Evaluating 20 -> Political ­Social Learning: ­Short-Term Memory and Cycles of Polarization†
# Evaluating 21 -> Sticky Wages on the Layoff Margin
# Evaluating 22 -> A Theory of Dynamic Inflation Targets
# Evaluating 23 -> Regulating Conglomerates: Evidence from an Energy Conservation Program in China
# Evaluating 24 -> Hedging When Applying: Simultaneous Search with Correlation
# Evaluating 25 -> Robust Monopoly Regulation
# Evaluating 26 -> The Benefits of Revealing Race: Evidence from Minority-Owned Local Businesses
# Evaluating 27 -> Empowering Adolescents to Transform Schools: Lessons from a Behavioral Targeting
# Evaluating 28 -> The Good Wife? Reputation Dynamics and Financial Decision-Making inside the Household
# Evaluating 29 -> Start-Up Costs and Market Power: Lessons from the Renewable Energy Transition
# Evaluating 30 -> JAQ of all trades: Job mismatch, firm productivity and managerial quality
# Evaluating 31 -> Household mobility and mortgage rate lock
# Evaluating 32 -> Asymmetric information, disagreement, and the valuation of debt and equity
# Evaluating 33 -> Constrained liquidity provision in currency markets
# Evaluating 34 -> The SOFR discount
# Evaluating 35 -> Growing the efficient frontier on panel trees
# Evaluating 36 -> Strategic arbitrage in segmented markets
# Evaluating 37 -> Global Business Networks
# Evaluating 38 -> The impact of impact investing
# Evaluating 39 -> Strategic insider trading and its consequences for outsiders: Evidence from the eighteenth century
# Evaluating 40 -> The Evolution of US Retail Concentration
# Evaluating 41 -> From Blue- to Steel-Collar Jobs: The Decline in Employment Gaps?
# Evaluating 42 -> Optimal Bank Reserve Remuneration and Capital Control Policy
# Evaluating 43 -> Permanent Income Shocks, Target Wealth, and the Wealth Gap
# Evaluating 44 -> Rational Inattention and the Business Cycle Effects of Productivity and News Shocks
# Evaluating 45 -> US Treasury Auctions: A High-Frequency Identification of Supply Shocks
# Evaluating 46 -> Enemies of the People
# Evaluating 47 -> Estimating Hysteresis Effects
# Evaluating 48 -> Singles, Couples, and Their Labor Supply: Long-Run Trends and Short-Run Fluctuations
# Evaluating 49 -> Medical Expenses and Saving in Retirement: The Case of the United States and Sweden
# Evaluating 50 -> Scooped! Estimating Rewards for Priority in Science
# Evaluating 51 -> College Attrition and the Dynamics of Information Revelation
# Evaluating 52 -> Financial Product Design in Decentralized Markets
# Evaluating 53 -> The Impact of Working-Memory Training on Children’s Cognitive and Noncognitive Skills
# Evaluating 54 -> Sorting with Teams
# Evaluating 55 -> Dissecting Mechanisms of Financial Crises: Intermediation and Sentiment
# Evaluating 56 -> Why Do Couples and Singles Save during Retirement? Household Heterogeneity and Its Aggregate Implications
# Evaluating 57 -> Targeting Precision Medicine: Evidence from Prenatal Screening
# Evaluating 58 -> Enhancing Human Capital in Children: A Case Study on Scaling
# Evaluating 59 -> Estimating the Technology of Children’s Skill Formation
# Evaluating 60 -> Carbon Returns across the Globe
# Evaluating 61 -> The Global Credit Spread Puzzle
# Evaluating 62 -> Bank Funding Risk, Reference Rates, and Credit Supply
# Evaluating 63 -> Uncovering the Hidden Effort Problem
# Evaluating 64 -> Sending Out an SMS: Automatic Enrollment Experiments for Overdraft Alerts
# Evaluating 65 -> Does Floor Trading Matter?
# Evaluating 66 -> Dynamic Competition in Negotiated Price Markets
# Evaluating 67 -> Equilibrium Data Mining and Data Abundance
# Evaluating 68 -> Intermediary Leverage Shocks and Funding Conditions
# Evaluating 69 -> Private Equity and Financial Stability: Evidence from Failed-Bank Resolution in the Crisis
# Evaluating 70 -> Missing Data in Asset Pricing Panels
# Evaluating 71 -> Long-Term Investors, Demand Shifts, and Yields
# Evaluating 72 -> Real Consequences of Shocks to Intermediaries Supplying Corporate Hedging Instruments
# Evaluating 73 -> Deconstructing the Yield Curve
# Evaluating 74 -> Dynamic Market Making with Asymmetric Information and Market Power
# Evaluating 75 -> The Imitation Game: How Encouraging Renegotiation Makes Good Borrowers Bad
# Evaluating 76 -> The Impact of Crisis-Period Interest Rate Declines on Distressed Borrowers
# Evaluating 77 -> Duration-Based Valuation of Corporate Bonds
# Evaluating 78 -> News Diffusion in Social Networks and Stock Market Reactions
# Evaluating 79 -> News and Asset Pricing: A High-Frequency Anatomy of the SDF
# Evaluating 80 -> Partially Linear Models under Data Combination
# Evaluating 81 -> Migration and the Value of Social Networks
# Evaluating 82 -> Transhumant Pastoralism, Climate Change, and Conflict in Africa
# Evaluating 83 -> Good Politicians: Experimental Evidence on Motivations for Political Candidacy and Government Performance
# Evaluating 84 -> The Causal Impact of Socio-Emotional Skills Training on Educational Success
# Evaluating 85 -> Private Sector Provision as an “Escape Valve”: The Mexico Diabetes Experiment
# Evaluating 86 -> Adaptive Estimation and Uniform Confidence Bands for Nonparametric Structural Functions and Elasticities
# Evaluating 87 -> Inefficient Automation
# Evaluating 88 -> Too Domestic to Fail: Liquidity Provision and National Champions
# Evaluating 89 -> Information Spillovers and Sovereign Debt: Theory Meets the Eurozone Crisis
# Evaluating 90 -> Rising Import Tariffs, Falling Exports: When Modern Supply Chains Meet Old-Style Protectionism
# Evaluating 91 -> Smart Thermostats, Automation, and Time-Varying Prices
# Evaluating 92 -> Staggered ­Difference-in-Differences in Gravity Settings: Revisiting the Effects of Trade Agreements
# Evaluating 93 -> The Simpler the Better? Threshold Effects of Energy Labels on Property Prices and Energy Efficiency Investments
# Evaluating 94 -> Trade Disruptions and Reshoring
# Evaluating 95 -> Do Carbon Offsets Offset Carbon?
# Evaluating 96 -> The Willingness to Pay for a Cooler Day: Evidence from 50 Years of Major League Baseball Games
# Evaluating 97 -> Better Alone? Evidence on the Costs of Intermunicipal Cooperation
# Evaluating 98 -> Media Coverage of Immigration and the Polarization of Attitudes
# Evaluating 99 -> Location, Location, Location
# Finish Evaluating 47 -> Estimating Hysteresis Effects
# Finish Evaluating 84 -> The Causal Impact of Socio-Emotional Skills Training on Educational Success
# Finish Evaluating 66 -> Dynamic Competition in Negotiated Price Markets
# Finish Evaluating 72 -> Real Consequences of Shocks to Intermediaries Supplying Corporate Hedging Instruments
# Finish Evaluating 35 -> Growing the efficient frontier on panel trees
# Finish Evaluating 41 -> From Blue- to Steel-Collar Jobs: The Decline in Employment Gaps?
# Finish Evaluating 91 -> Smart Thermostats, Automation, and Time-Varying Prices
# Finish Evaluating 64 -> Sending Out an SMS: Automatic Enrollment Experiments for Overdraft Alerts
# Finish Evaluating 25 -> Robust Monopoly Regulation
# Finish Evaluating 51 -> College Attrition and the Dynamics of Information Revelation
# Finish Evaluating 14 -> Present Bias Amplifies the Household Balance-Sheet Channels of Macroeconomic Policy
# Finish Evaluating 29 -> Start-Up Costs and Market Power: Lessons from the Renewable Energy Transition
# Finish Evaluating 46 -> Enemies of the People
# Finish Evaluating 3 -> PERSUASION MEETS DELEGATION
# Finish Evaluating 60 -> Carbon Returns across the Globe
# Finish Evaluating 22 -> A Theory of Dynamic Inflation Targets
# Finish Evaluating 94 -> Trade Disruptions and Reshoring
# Finish Evaluating 87 -> Inefficient Automation
# Finish Evaluating 74 -> Dynamic Market Making with Asymmetric Information and Market Power
# Finish Evaluating 44 -> Rational Inattention and the Business Cycle Effects of Productivity and News Shocks
# Finish Evaluating 48 -> Singles, Couples, and Their Labor Supply: Long-Run Trends and Short-Run Fluctuations
# Finish Evaluating 32 -> Asymmetric information, disagreement, and the valuation of debt and equity
# Finish Evaluating 23 -> Regulating Conglomerates: Evidence from an Energy Conservation Program in China
# Finish Evaluating 16 -> EVOLUTION VS. CREATIONISM IN THE CLASSROOM: THE LASTING EFFECTS OF SCIENCE EDUC A TION
# Finish Evaluating 42 -> Optimal Bank Reserve Remuneration and Capital Control Policy
# Finish Evaluating 7 -> Seeding a Simple Contagion
# Finish Evaluating 82 -> Transhumant Pastoralism, Climate Change, and Conflict in Africa
# Finish Evaluating 96 -> The Willingness to Pay for a Cooler Day: Evidence from 50 Years of Major League Baseball Games
# Finish Evaluating 83 -> Good Politicians: Experimental Evidence on Motivations for Political Candidacy and Government Performance
# Finish Evaluating 30 -> JAQ of all trades: Job mismatch, firm productivity and managerial quality
# Finish Evaluating 71 -> Long-Term Investors, Demand Shifts, and Yields
# Finish Evaluating 36 -> Strategic arbitrage in segmented markets
# Finish Evaluating 50 -> Scooped! Estimating Rewards for Priority in Science
# Finish Evaluating 21 -> Sticky Wages on the Layoff Margin
# Finish Evaluating 85 -> Private Sector Provision as an “Escape Valve”: The Mexico Diabetes Experiment
# Finish Evaluating 89 -> Information Spillovers and Sovereign Debt: Theory Meets the Eurozone Crisis
# Finish Evaluating 61 -> The Global Credit Spread Puzzle
# Finish Evaluating 80 -> Partially Linear Models under Data Combination
# Finish Evaluating 37 -> Global Business Networks
# Finish Evaluating 2 -> Ambiguous Contracts
# Finish Evaluating 98 -> Media Coverage of Immigration and the Polarization of Attitudes
# Finish Evaluating 49 -> Medical Expenses and Saving in Retirement: The Case of the United States and Sweden
# Finish Evaluating 17 -> THE LONG-RUN IMPACTS OF PUBLIC INDUSTRIAL INVESTMENT ON LOCAL DEVELOPMENT AND ECONOMIC MOBILITY: EVIDENCE FROM WORLD WAR II
# Finish Evaluating 11 -> A Welfare Analysis of Tax Audits across the Income Distribution
# Finish Evaluating 76 -> The Impact of Crisis-Period Interest Rate Declines on Distressed Borrowers
# Finish Evaluating 55 -> Dissecting Mechanisms of Financial Crises: Intermediation and Sentiment
# Finish Evaluating 81 -> Migration and the Value of Social Networks
# Finish Evaluating 62 -> Bank Funding Risk, Reference Rates, and Credit Supply
# Finish Evaluating 99 -> Location, Location, Location
# Finish Evaluating 73 -> Deconstructing the Yield Curve
# Finish Evaluating 86 -> Adaptive Estimation and Uniform Confidence Bands for Nonparametric Structural Functions and Elasticities
# Finish Evaluating 53 -> The Impact of Working-Memory Training on Children’s Cognitive and Noncognitive Skills
# Finish Evaluating 31 -> Household mobility and mortgage rate lock
# Finish Evaluating 33 -> Constrained liquidity provision in currency markets
# Finish Evaluating 26 -> The Benefits of Revealing Race: Evidence from Minority-Owned Local Businesses
# Finish Evaluating 69 -> Private Equity and Financial Stability: Evidence from Failed-Bank Resolution in the Crisis
# Finish Evaluating 67 -> Equilibrium Data Mining and Data Abundance
# Finish Evaluating 28 -> The Good Wife? Reputation Dynamics and Financial Decision-Making inside the Household
# Finish Evaluating 68 -> Intermediary Leverage Shocks and Funding Conditions
# Finish Evaluating 38 -> The impact of impact investing
# Finish Evaluating 0 -> The Political Economy of Zero-Sum Thinking
# Finish Evaluating 5 -> The Impacts of Managerial Autonomy on Firm Outcomes
# Finish Evaluating 90 -> Rising Import Tariffs, Falling Exports: When Modern Supply Chains Meet Old-Style Protectionism
# Finish Evaluating 40 -> The Evolution of US Retail Concentration
# Finish Evaluating 43 -> Permanent Income Shocks, Target Wealth, and the Wealth Gap
# Finish Evaluating 54 -> Sorting with Teams
# Finish Evaluating 57 -> Targeting Precision Medicine: Evidence from Prenatal Screening
# Finish Evaluating 8 -> CAUTION AND REFERENCE EFFECTS
# Finish Evaluating 12 -> War Reparations, Structural Change, and Intergenerational Mobility
# Finish Evaluating 27 -> Empowering Adolescents to Transform Schools: Lessons from a Behavioral Targeting
# Finish Evaluating 78 -> News Diffusion in Social Networks and Stock Market Reactions
# Finish Evaluating 63 -> Uncovering the Hidden Effort Problem
# Finish Evaluating 70 -> Missing Data in Asset Pricing Panels
# Finish Evaluating 24 -> Hedging When Applying: Simultaneous Search with Correlation
# Finish Evaluating 75 -> The Imitation Game: How Encouraging Renegotiation Makes Good Borrowers Bad
# Finish Evaluating 1 -> Social Media and Collective Action in China
# Finish Evaluating 58 -> Enhancing Human Capital in Children: A Case Study on Scaling
# Finish Evaluating 19 -> MANDATORY NOTICE OF LAYOFF, JOB SEARCH, AND EFFICIENCY
# Finish Evaluating 18 -> Believed Gender Differences in Social Preferences
# Finish Evaluating 34 -> The SOFR discount
# Finish Evaluating 20 -> Political ­Social Learning: ­Short-Term Memory and Cycles of Polarization†
# Finish Evaluating 93 -> The Simpler the Better? Threshold Effects of Energy Labels on Property Prices and Energy Efficiency Investments
# Finish Evaluating 10 -> Stories, Statistics, and Memory
# Finish Evaluating 56 -> Why Do Couples and Singles Save during Retirement? Household Heterogeneity and Its Aggregate Implications
# Finish Evaluating 95 -> Do Carbon Offsets Offset Carbon?
# Finish Evaluating 88 -> Too Domestic to Fail: Liquidity Provision and National Champions
# Finish Evaluating 13 -> THE DYNAMICS OF ABUSIVE RELATIONSHIPS
# Finish Evaluating 52 -> Financial Product Design in Decentralized Markets
# Finish Evaluating 77 -> Duration-Based Valuation of Corporate Bonds
# Finish Evaluating 65 -> Does Floor Trading Matter?
# Finish Evaluating 59 -> Estimating the Technology of Children’s Skill Formation
# Finish Evaluating 97 -> Better Alone? Evidence on the Costs of Intermunicipal Cooperation
# Finish Evaluating 45 -> US Treasury Auctions: A High-Frequency Identification of Supply Shocks
# Finish Evaluating 15 -> Overinference from Weak Signals and Underinference from Strong Signals
# Finish Evaluating 92 -> Staggered ­Difference-in-Differences in Gravity Settings: Revisiting the Effects of Trade Agreements
# Finish Evaluating 6 -> Sparse Network Asymptotics for Logistic Regression Under Possible Misspecification
# Finish Evaluating 39 -> Strategic insider trading and its consequences for outsiders: Evidence from the eighteenth century
# Finish Evaluating 4 -> Minimum Wages, Efficiency, and Welfare
# Finish Evaluating 9 -> HISTORY’S MASTERS: THE EFFECT OF EUROPEAN MONARCHS ON STATE PERFORMANCE
# Finish Evaluating 79 -> News and Asset Pricing: A High-Frequency Anatomy of the SDF
# PROCESSING CHUNK 2 of 11
# Evaluating 100 -> Human capital, self‑esteem, and income inequality
# Evaluating 101 -> Elites and health infrastructure improvements in industrializing regimes
# Evaluating 102 -> Labor scarcity, technology adoption and innovation: evidence from the cholera pandemics in 19th century France
# Evaluating 103 -> Nepotism vs. intergenerational transmission of human capital in Academia (1088–1800)
# Evaluating 104 -> Women legislators and economic performance
# Evaluating 105 -> On the coevolution of individualism and institutions
# Evaluating 106 -> Social mobility and economic development
# Evaluating 107 -> Missions, fertility transition, and the reversal of fortunes: evidence from border discontinuities in the emirates of Nigeria
# Evaluating 108 -> Automation and unemployment: help is on the way
# Evaluating 109 -> Educational quality and disparities in income and growth across countries
# Evaluating 110 -> Joint search over the life cycle
# Evaluating 111 -> Wealth shocks and portfolio choice
# Evaluating 112 -> Style over substance? Advertising, innovation, and endogenous market structure
# Evaluating 113 -> Shaping inequality and intergenerational persistence of poverty: Free college or better schools?
# Evaluating 114 -> Occupational reallocation within and across firms: Implications for labor market polarization
# Evaluating 115 -> How to fund unemployment insurance with informality and false claims: Evidence from Senegal
# Evaluating 116 -> Singles, couples, time-averaging, and taxation
# Evaluating 117 -> Income differences and health disparities: Roles of preventive vs. curative medicine
# Evaluating 118 -> The alpha beta gamma of the labor market
# Evaluating 119 -> Heterogeneous job ladders
# Evaluating 120 -> Bootstrapping out-of-sample predictability tests with real-time data
# Evaluating 121 -> Pseudo-variance quasi-maximum likelihood estimation of semi-parametric time series models
# Evaluating 122 -> Simulation error and numerical instability in estimating random coefficient logit demand models
# Evaluating 123 -> On testing for spatial or social network dependence in panel data allowing for network variability
# Evaluating 124 -> Validating approximate slope homogeneity in large panels
# Evaluating 125 -> Natural disasters as macroeconomic tail risks
# Evaluating 126 -> The robust F-statistic as a test for weak instruments
# Evaluating 127 -> Uniform inference for cointegrated vector autoregressive processes
# Evaluating 128 -> Shrinkage estimators for periodic autoregressions
# Evaluating 129 -> From LATE to ATE: A Bayesian approach☆
# Evaluating 130 -> RACIAL SEGREGATION IN HOUSING MARKETS AND THE EROSION OF BLACK WEALTH
# Evaluating 131 -> GETTING THE PRICE RIGHT? THE IMPACT OF COMPETITIVE BIDDING IN THE MEDICARE PROGRAM
# Evaluating 132 -> WHY DON’T WE SLEEP ENOUGH? A FIELD EXPERIMENT AMONG COLLEGE STUDENTS
# Evaluating 133 -> The Gender Wage Gap in an Online Labor Market: The Cost of Interruptions
# Evaluating 134 -> ON THE ECONOMIC CONSEQUENCES OF MASS SHOOTINGS
# Evaluating 135 -> PEER ADVICE ON FINANCIAL DECISIONS: A CASE OF THE BLIND LEADING THE BLIND?
# Evaluating 136 -> THE INTELLECTUAL SPOILS OF WAR? DEFENSE R&D, PRODUCTIVITY, AND INTERNATIONAL SPILLOVERS
# Evaluating 137 -> What Do Cross-Country Surveys Tell Us About Social Capital?
# Evaluating 138 -> WHAT HAPPENS TO WORKERS AT FIRMS THAT AUTOMATE?
# Evaluating 139 -> IMMIGRATION LOTTERY DESIGN: ENGINEERED AND COINCIDENTAL CONSEQUENCES OF H-1B REFORMS
# Evaluating 140 -> RESISTING EDUCATION
# Evaluating 141 -> Labor Unions and the Electoral Consequences of Trade Liberalization
# Evaluating 142 -> Information Technology, Improved Access, and Use of Prescription Drugs
# Evaluating 143 -> Decentralized Targeting of Agricultural Credit Programs: Private Versus Political Intermediaries
# Evaluating 144 -> Downside and Upside Uncertainty Shocks
# Evaluating 145 -> Regulating Platform Fees under Price Parity
# Evaluating 146 -> THE IMPACT OF NGO-PROVIDED AID ON GOVERNMENT CAPACITY: EVIDENCE FROM UGANDA
# Evaluating 147 -> FIRMS’ INFLATION EXPECTATIONS: NEW EVIDENCE FROM FRANCE
# Evaluating 148 -> Unintended Consequences of the Global Derivatives Market Reform
# Evaluating 149 -> Electoral Campaigns as Dynamic Contests
# Evaluating 150 -> STRATEGIC CONFORMITY OR ANTI-CONFORMITY TO AVOID PUNISHMENT AND ATTRACT REWARD
# Evaluating 151 -> TELEVISION AND ACADEMIC ACHIEVEMENT: EVIDENCE FROM THE DIGITAL TELEVISION TRANSITION IN THE UK
# Evaluating 152 -> WHO’S AFRAID OF POLICY EXPERIMENTS?
# Evaluating 153 -> Productivity Growth and Workers’ Job Transitions: Evidence from Census MicrodataEvaluating 154 -> Returns to Labour Mobility
#
# Evaluating 155 -> Measuring Social Benefits of Media Coverage: How Coverage of Climate Change Affects Behaviour
# Evaluating 156 -> Score Disclosure
# Evaluating 157 -> Healthcare Appointments as Commitment Devices
# Evaluating 158 -> House Prices and Misallocation: The Impact of the Collateral Channel on Productivity
# Evaluating 159 -> Do Motivated Classmates Matter for Educational Success?
# Evaluating 160 -> Measuring Labor Market Power in Developing Countries: Evidence from Colombian Plants
# Evaluating 161 -> Does Job Search Assistance Reduce Unemployment? Evidence on Displacement Effects and Mechanisms
# Evaluating 162 -> Effects of Conﬁdential Access to Oral Contraception in Late Adolescence on Work and Earnings
# Evaluating 163 -> The Impact of the Retirement Slowdown on the US Youth Labor Market
# Evaluating 164 -> Social Transfers and Spatial Distortions
# Evaluating 165 -> Marginalized and Overlooked? Minoritized Groups and the Adoption of New Scientific Ideas
# Evaluating 166 -> Promotions, Adverse Selection, and Efficiency
# Evaluating 167 -> The Efficacy of Tournaments for Nonroutine Team Tasks
# Evaluating 168 -> The Intergenerational Effects of the Vietnam Draft on Risky Behaviors
# Evaluating 169 -> Physicians Treating Physicians: Relational and Informational Advantages in Treatment and Survival
# Evaluating 170 -> The Great Recession and the Widening Income Gap between Alumni of Elite and Less Selective Universities
# Evaluating 171 -> Clean Identification? The Effects of the Clean Air Act on Air Pollution, Exposure Disparities, and House Prices
# Evaluating 172 -> Mental Health Consequences of Correctional Sentencing
# Evaluating 173 -> Policymaking, Trust, and the Demand for Public Services: Evidence from a Mass Sterilization Campaign
# Evaluating 174 -> Spillover, Efficiency, and Equity Effects of Regional Firm Subsidies
# Evaluating 175 -> Fighting Poverty One Family at a Time: Experimental Evidence from an Intervention with Holistic, Individualized, Wraparound Services
# Evaluating 176 -> Who Bears the Burden of Local Taxes?
# Evaluating 177 -> Uncharted Waters: Effects of Maritime Emission Regulation
# Evaluating 178 -> The Impact of Provider Payments on Health Care Utilization of Low-Income Individuals: Evidence from Medicare and Medicaid
# Evaluating 179 -> Electronic Payment Technology and Tax Compliance: Evidence from Uruguay’s Financial Inclusion Reform
# Evaluating 180 -> Strategic Reneging and Market Power in Sequential Markets
# Evaluating 181 -> Optimal Incentive Contracts With Bonus Caps
# Evaluating 182 -> Why Do Retail Prices Fall During Seasonal Demand Peaks?
# Evaluating 183 -> Hybrid platform model: monopolistic competition and a dominant firm
# Evaluating 184 -> Market transparency and consumer search—Evidence from the German retail gasoline market
# Evaluating 185 -> Transparency and Policymaking with Endogenous Information Provision
# Evaluating 186 -> Optimal pricing scheme for addictive goods
# Evaluating 187 -> The Competitive Conduct of Consumer Cooperatives
# Evaluating 188 -> Steering via algorithmic recommendations
# Evaluating 189 -> The Effects of Advertising Disclosure Regulations on Social Media: Evidence From Instagram
# Evaluating 190 -> Capital flows: The role of investment fund portfolio managers
# Evaluating 191 -> A many-location home market effect and a home biased geography
# Evaluating 192 -> Two illustrations of the quantity theory of money reloaded
# Evaluating 193 -> Avoiding sovereign default contagion: A normative analysis
# Evaluating 194 -> Trade flows and exchange rates: Importers, exporters and products
# Evaluating 195 -> Banking complexity in the global economy✩
# Evaluating 196 -> Import processing and trade costs
# Evaluating 197 -> The cleanup of US manufacturing through pollution offshoring
# Evaluating 198 -> Spillovers of US interest rates: Monetary policy & information effects
# Evaluating 199 -> Term premia and credit risk in emerging markets: The role of U.S. monetary policy
# Finish Evaluating 190 -> Capital flows: The role of investment fund portfolio managers
# Finish Evaluating 160 -> Measuring Labor Market Power in Developing Countries: Evidence from Colombian Plants
# Finish Evaluating 136 -> THE INTELLECTUAL SPOILS OF WAR? DEFENSE R&D, PRODUCTIVITY, AND INTERNATIONAL SPILLOVERS
# Finish Evaluating 167 -> The Efficacy of Tournaments for Nonroutine Team Tasks
# Finish Evaluating 104 -> Women legislators and economic performance
# Finish Evaluating 135 -> PEER ADVICE ON FINANCIAL DECISIONS: A CASE OF THE BLIND LEADING THE BLIND?
# Finish Evaluating 115 -> How to fund unemployment insurance with informality and false claims: Evidence from Senegal
# Finish Evaluating 126 -> The robust F-statistic as a test for weak instruments
# Finish Evaluating 110 -> Joint search over the life cycle
# Finish Evaluating 124 -> Validating approximate slope homogeneity in large panels
# Finish Evaluating 141 -> Labor Unions and the Electoral Consequences of Trade Liberalization
# Finish Evaluating 116 -> Singles, couples, time-averaging, and taxation
# Finish Evaluating 128 -> Shrinkage estimators for periodic autoregressions
# Finish Evaluating 195 -> Banking complexity in the global economy✩
# Finish Evaluating 184 -> Market transparency and consumer search—Evidence from the German retail gasoline market
# Finish Evaluating 119 -> Heterogeneous job ladders
# Finish Evaluating 154 -> Returns to Labour Mobility
# Finish Evaluating 111 -> Wealth shocks and portfolio choice
# Finish Evaluating 168 -> The Intergenerational Effects of the Vietnam Draft on Risky Behaviors
# Finish Evaluating 156 -> Score Disclosure
# Finish Evaluating 148 -> Unintended Consequences of the Global Derivatives Market Reform
# Finish Evaluating 147 -> FIRMS’ INFLATION EXPECTATIONS: NEW EVIDENCE FROM FRANCE
# Finish Evaluating 175 -> Fighting Poverty One Family at a Time: Experimental Evidence from an Intervention with Holistic, Individualized, Wraparound Services
# Finish Evaluating 179 -> Electronic Payment Technology and Tax Compliance: Evidence from Uruguay’s Financial Inclusion Reform
# Finish Evaluating 106 -> Social mobility and economic development
# Finish Evaluating 127 -> Uniform inference for cointegrated vector autoregressive processes
# Finish Evaluating 101 -> Elites and health infrastructure improvements in industrializing regimes
# Finish Evaluating 112 -> Style over substance? Advertising, innovation, and endogenous market structure
# Finish Evaluating 138 -> WHAT HAPPENS TO WORKERS AT FIRMS THAT AUTOMATE?
# Finish Evaluating 177 -> Uncharted Waters: Effects of Maritime Emission Regulation
# Finish Evaluating 198 -> Spillovers of US interest rates: Monetary policy & information effects
# Finish Evaluating 131 -> GETTING THE PRICE RIGHT? THE IMPACT OF COMPETITIVE BIDDING IN THE MEDICARE PROGRAM
# Finish Evaluating 140 -> RESISTING EDUCATION
# Finish Evaluating 144 -> Downside and Upside Uncertainty Shocks
# Finish Evaluating 130 -> RACIAL SEGREGATION IN HOUSING MARKETS AND THE EROSION OF BLACK WEALTH
# Finish Evaluating 180 -> Strategic Reneging and Market Power in Sequential Markets
# Finish Evaluating 186 -> Optimal pricing scheme for addictive goods
# Finish Evaluating 113 -> Shaping inequality and intergenerational persistence of poverty: Free college or better schools?
# Finish Evaluating 102 -> Labor scarcity, technology adoption and innovation: evidence from the cholera pandemics in 19th century France
# Finish Evaluating 181 -> Optimal Incentive Contracts With Bonus Caps
# Finish Evaluating 143 -> Decentralized Targeting of Agricultural Credit Programs: Private Versus Political Intermediaries
# Finish Evaluating 100 -> Human capital, self‑esteem, and income inequality
# Finish Evaluating 162 -> Effects of Conﬁdential Access to Oral Contraception in Late Adolescence on Work and Earnings
# Finish Evaluating 158 -> House Prices and Misallocation: The Impact of the Collateral Channel on Productivity
# Finish Evaluating 199 -> Term premia and credit risk in emerging markets: The role of U.S. monetary policy
# Finish Evaluating 164 -> Social Transfers and Spatial Distortions
# Finish Evaluating 149 -> Electoral Campaigns as Dynamic Contests
# Finish Evaluating 133 -> The Gender Wage Gap in an Online Labor Market: The Cost of Interruptions
# Finish Evaluating 121 -> Pseudo-variance quasi-maximum likelihood estimation of semi-parametric time series models
# Finish Evaluating 169 -> Physicians Treating Physicians: Relational and Informational Advantages in Treatment and Survival
# Finish Evaluating 107 -> Missions, fertility transition, and the reversal of fortunes: evidence from border discontinuities in the emirates of Nigeria
# Finish Evaluating 159 -> Do Motivated Classmates Matter for Educational Success?
# Finish Evaluating 174 -> Spillover, Efficiency, and Equity Effects of Regional Firm Subsidies
# Finish Evaluating 103 -> Nepotism vs. intergenerational transmission of human capital in Academia (1088–1800)
# Finish Evaluating 114 -> Occupational reallocation within and across firms: Implications for labor market polarization
# Finish Evaluating 129 -> From LATE to ATE: A Bayesian approach☆
# Finish Evaluating 170 -> The Great Recession and the Widening Income Gap between Alumni of Elite and Less Selective Universities
# Finish Evaluating 145 -> Regulating Platform Fees under Price Parity
# Finish Evaluating 166 -> Promotions, Adverse Selection, and Efficiency
# Finish Evaluating 188 -> Steering via algorithmic recommendations
# Finish Evaluating 161 -> Does Job Search Assistance Reduce Unemployment? Evidence on Displacement Effects and Mechanisms
# Finish Evaluating 146 -> THE IMPACT OF NGO-PROVIDED AID ON GOVERNMENT CAPACITY: EVIDENCE FROM UGANDA
# Finish Evaluating 197 -> The cleanup of US manufacturing through pollution offshoring
# Finish Evaluating 165 -> Marginalized and Overlooked? Minoritized Groups and the Adoption of New Scientific Ideas
# Finish Evaluating 185 -> Transparency and Policymaking with Endogenous Information Provision
# Finish Evaluating 171 -> Clean Identification? The Effects of the Clean Air Act on Air Pollution, Exposure Disparities, and House Prices
# Finish Evaluating 139 -> IMMIGRATION LOTTERY DESIGN: ENGINEERED AND COINCIDENTAL CONSEQUENCES OF H-1B REFORMS
# Finish Evaluating 192 -> Two illustrations of the quantity theory of money reloaded
# Finish Evaluating 157 -> Healthcare Appointments as Commitment Devices
# Finish Evaluating 196 -> Import processing and trade costs
# Finish Evaluating 187 -> The Competitive Conduct of Consumer Cooperatives
# Finish Evaluating 151 -> TELEVISION AND ACADEMIC ACHIEVEMENT: EVIDENCE FROM THE DIGITAL TELEVISION TRANSITION IN THE UK
# Finish Evaluating 176 -> Who Bears the Burden of Local Taxes?
# Finish Evaluating 117 -> Income differences and health disparities: Roles of preventive vs. curative medicine
# Finish Evaluating 191 -> A many-location home market effect and a home biased geography
# Finish Evaluating 142 -> Information Technology, Improved Access, and Use of Prescription Drugs
# Finish Evaluating 105 -> On the coevolution of individualism and institutions
# Finish Evaluating 109 -> Educational quality and disparities in income and growth across countries
# Finish Evaluating 132 -> WHY DON’T WE SLEEP ENOUGH? A FIELD EXPERIMENT AMONG COLLEGE STUDENTS
# Finish Evaluating 125 -> Natural disasters as macroeconomic tail risks
# Finish Evaluating 194 -> Trade flows and exchange rates: Importers, exporters and products
# Finish Evaluating 108 -> Automation and unemployment: help is on the way
# Finish Evaluating 118 -> The alpha beta gamma of the labor market
# Finish Evaluating 120 -> Bootstrapping out-of-sample predictability tests with real-time data
# Finish Evaluating 163 -> The Impact of the Retirement Slowdown on the US Youth Labor Market
# Finish Evaluating 155 -> Measuring Social Benefits of Media Coverage: How Coverage of Climate Change Affects Behaviour
# Finish Evaluating 183 -> Hybrid platform model: monopolistic competition and a dominant firm
# Finish Evaluating 189 -> The Effects of Advertising Disclosure Regulations on Social Media: Evidence From Instagram
# Finish Evaluating 152 -> WHO’S AFRAID OF POLICY EXPERIMENTS?
# Finish Evaluating 137 -> What Do Cross-Country Surveys Tell Us About Social Capital?
# Finish Evaluating 122 -> Simulation error and numerical instability in estimating random coefficient logit demand models
# Finish Evaluating 182 -> Why Do Retail Prices Fall During Seasonal Demand Peaks?
# Finish Evaluating 173 -> Policymaking, Trust, and the Demand for Public Services: Evidence from a Mass Sterilization Campaign
# Finish Evaluating 134 -> ON THE ECONOMIC CONSEQUENCES OF MASS SHOOTINGS
# Finish Evaluating 153 -> Productivity Growth and Workers’ Job Transitions: Evidence from Census Microdata
# Finish Evaluating 178 -> The Impact of Provider Payments on Health Care Utilization of Low-Income Individuals: Evidence from Medicare and Medicaid
# Finish Evaluating 172 -> Mental Health Consequences of Correctional Sentencing
# Finish Evaluating 150 -> STRATEGIC CONFORMITY OR ANTI-CONFORMITY TO AVOID PUNISHMENT AND ATTRACT REWARD
# Finish Evaluating 123 -> On testing for spatial or social network dependence in panel data allowing for network variability
# Finish Evaluating 193 -> Avoiding sovereign default contagion: A normative analysis
# PROCESSING CHUNK 3 of 11
# Evaluating 200 -> Testing above the limit: Drinking water contamination and test scores
# Evaluating 201 -> Effects of speed-schools in Niger
# Evaluating 202 -> (Not) Everyone can be a winner — The role of payoff interdependence for redistribution
# Evaluating 203 -> Campaign contributions and legislative behavior: Evidence from U.S. Congress
# Evaluating 204 -> Recession experiences during early adulthood shape prosocial attitudes later in life
# Evaluating 205 -> Effects of restrictive abortion legislation on cohort mortality: evidence from 19th century law variation
# Evaluating 206 -> Property taxation as compensation for local externalities: Evidence from large plants
# Evaluating 207 -> OK Boomer: Generational differences in teacher quality
# Evaluating 208 -> Neighborhoods, Perceived Inequality, and Preferences for Redistribution: Evidence from Barcelona☆
# Evaluating 209 -> Vote early and vote often? Detecting electoral fraud from the timing of 19th century elections
# Evaluating 210 -> Leveraging Unlabeled Data for Superior ROC Curve Estimation via a Semiparametric Approach
# Evaluating 211 -> A Nonparametric Bayesian Estimator of Copula Density with Applications to Financial Market
# Evaluating 212 -> Instability of Factor Strength in Asset Returns
# Evaluating 213 -> Precision Least Squares: Estimation and Inference in High-Dimensions
# Evaluating 214 -> Conditional Score Residuals and Diagnostic Analysis of Serial Dependence in Time Series Models
# Evaluating 215 -> Bayesian Inference of Vector Autoregressions with Tensor Decompositions
# Evaluating 216 -> A Revealed Preference Approach to Identification and Inference in Producer-Consumer Models
# Evaluating 217 -> Estimation and Inference for a Semiparametric Time–Varying Panel Data Model
# Evaluating 218 -> Model Selection for Multivalued-Treatment Policy Learning in Observational Studies
# Evaluating 219 -> Dynamic Modeling via Autoregressive Conditional GB2 for Cross-Sectional Maxima of Financial Time Series Data
# Evaluating 220 -> The benefits of forecasting inflation with machine learning: New evidence
# Evaluating 221 -> Uncertainty, Skewness, and the Business Cycle Through the MIDAS Lens
# Evaluating 222 -> The boosted Hodrick-Prescott filter is more general than you might think
# Evaluating 223 -> Multiple Structural Breaks in Interactive Effects Panel Data Models
# Evaluating 224 -> Quantile-Based Test for Heterogeneous Treatment Effects
# Evaluating 225 -> Fast and order-invariant inference in Bayesian VARs with nonparametric shocks
# Evaluating 226 -> Agglomerative hierarchical clustering for selecting valid instrumental variables
# Evaluating 227 -> Exploiting News Analytics for Volatility Forecasting
# Evaluating 228 -> Nowcasting Norwegian household consumption with debit card transaction data
# Evaluating 229 -> Bonferroni-Type Tests for Return Predictability With Possibly Trending Predictors
# Evaluating 230 -> Aid allocation with optimal monitoring: Theory and policy
# Evaluating 231 -> Do entrepreneurial skills unlock opportunities for online freelancing?
# Evaluating 232 -> Early maternity and paternity. Effects on educational trajectories
# Evaluating 233 -> The local human capital costs of oil exploitation
# Evaluating 234 -> Are students really biased against female professors? — Experimental evidence from India
# Evaluating 235 -> What matters for the decision to study abroad? A lab-in-the-field experiment in Cape Verde
# Evaluating 236 -> Better strategies for saving more: Evidence from three interventions in Chile
# Evaluating 237 -> On the properties of the two main types of global poverty lines
# Evaluating 238 -> Better together? Group incentives and the demand for prevention
# Evaluating 239 -> Labor market effects of bounds on domestic outsourcing
# Evaluating 240 -> The dynamics of project standards
# Evaluating 241 -> Modeling machine learning: A cognitive economic approach
# Evaluating 242 -> Achieving safety: Personal, private, and public provision
# Evaluating 243 -> Network-based peer monitoring design
# Evaluating 244 -> Optimal discriminatory disclosure
# Evaluating 245 -> Binary mechanisms under privacy-preserving noise
# Evaluating 246 -> Widening access in university admissions
# Evaluating 247 -> General theory of equilibrium in models with complementarities
# Evaluating 248 -> Evolving wars of attrition
# Evaluating 249 -> Selling signals
# Evaluating 250 -> Lifetime and Intergenerational Consequences of Poor Childhood HealthEvaluating 251 -> Beyond Reading, Writing, and Arithmetic: The Role of Teachers and Schools in Reporting Child Maltreatment
#
# Evaluating 252 -> Managing Long Working Hours: Evidence from a Management Practice Survey
# Evaluating 253 -> A Field Experiment on Labor Market Speeddates for Unemployed Workers
# Evaluating 254 -> Stacking the Deck for Employment Success: Labor Market Returns to Stackable Credentials
# Evaluating 255 -> The Effects of Increasing the Eligibility Age for Public Pension on Individual Labor Supply: Evidence from Japan
# Evaluating 256 -> Beyond Treatment Exposure: The Impact of the Timing of Early Interventions on Child and Maternal Health
# Evaluating 257 -> The Effects of Sun Intensity during Pregnancy and in the First 12 Months of Life on Childhood Obesity
# Evaluating 258 -> Labor Market Experience and Returns to College Education in Fast-Growing Economies
# Evaluating 259 -> Suddenly Married: Joint Taxation and the Labor Supply of Same-Sex Married Couples after United States v. Windsor
# Evaluating 260 -> Do equal employment opportunity statements encourage racial minorities? evidence from a large natural field experiment
# Evaluating 261 -> Explaining institutional technology
# Evaluating 262 -> On explaining why the (human) world is rich✰
# Evaluating 263 -> Market competition and the adoption of clean technology: Evidence from the taxi industry
# Evaluating 264 -> Monetary policy interactions: The policy rate, asset purchases, and optimal policy with an interest rate peg
# Evaluating 265 -> Institutional diversity and innovative recombination
# Evaluating 266 -> Strategic parental investments in a competitive marriage market
# Evaluating 267 -> Fiscal tightening and skills mismatch
# Evaluating 268 -> Make-up strategies with incomplete markets and bounded rationality
# Evaluating 269 -> Recourse and (strategic) mortgage defaults: Evidence from changes in housing market laws
# Evaluating 270 -> R&D, Market Power, and the Cyclicality of Employment
# Evaluating 271 -> Spatial Dependence via the Internal Capital Markets of U.S. Global Banks
# Evaluating 272 -> Government Spending, Debt Management, and Wealth and Income Inequality in a Growing Monetary Economy
# Evaluating 273 -> Regulatory Capital Management to Exceed Thresholds
# Evaluating 274 -> Identifying the Depreciation Rate of Durables from Marginal Spending Responses
# Evaluating 275 -> Social Media Emotions and IPO Returns
# Evaluating 276 -> Reconsidering the Fed’s Inflation Forecasting Advantage
# Evaluating 277 -> The Life Cycle of Systemic Risk and Crises
# Evaluating 278 -> The Effect of Job Loss on Bank Account Ownership
# Evaluating 279 -> Potential Output Pessimism and Austerity in the European Union
# Evaluating 280 -> Carbon management ability and climate risk exposure: An international investigation
# Evaluating 281 -> Rest and financial judgments: The impact of holidays on analyst accuracy
# Evaluating 282 -> Stochastic arbitrage with market index options
# Evaluating 283 -> Do activists align with larger mutual funds?
# Evaluating 284 -> Discretion in pay ratio estimation
# Evaluating 285 -> Dissecting the return-predicting power of risk-neutral variance
# Evaluating 286 -> How should we measure the performance of corporate bond mutual funds? Evaluating model quality and impact on inferences☆
# Evaluating 287 -> Local boy does good: The effect of CSR activities on firm value
# Evaluating 288 -> Fear propagation and return dynamics
# Evaluating 289 -> Fiduciary duty and corporate social responsibility: Evidence from corporate opportunity waiver
# Evaluating 290 -> Mandatory Integration Agreements for Unemployed Job Seekers: A Randomized Controlled Field Experiment in Germany
# Evaluating 291 -> The Unprecedented Fall in U.S. Revolving Credit
# Evaluating 292 -> Ideal Default for Resolving Disputes Efficiently
# Evaluating 293 -> Age Discontinuity and Nonemployment Benefit Policy Evaluation Through the Lens of Job Search Theory
# Evaluating 294 -> Health, Health Insurance, and Inequality
# Evaluating 295 -> UNEQUAL PEACE
# Evaluating 296 -> Constant Discounting, Temporal Instability, and Dynamic Inconsistency in Denmark: A Longitudinal Field Experiment
# Evaluating 297 -> Productive Robots and Industrial Employment: The Role of National Innovation Systems
# Evaluating 298 -> Condorcet Consistency and Pairwise Justifiability Under Variable Agendas
# Evaluating 299 -> Pensions, Income Taxes, and Homeownership: A Cross-Country Analysis
# Finish Evaluating 279 -> Potential Output Pessimism and Austerity in the European Union
# Finish Evaluating 273 -> Regulatory Capital Management to Exceed Thresholds
# Finish Evaluating 297 -> Productive Robots and Industrial Employment: The Role of National Innovation Systems
# Finish Evaluating 249 -> Selling signals
# Finish Evaluating 231 -> Do entrepreneurial skills unlock opportunities for online freelancing?
# Finish Evaluating 271 -> Spatial Dependence via the Internal Capital Markets of U.S. Global Banks
# Finish Evaluating 257 -> The Effects of Sun Intensity during Pregnancy and in the First 12 Months of Life on Childhood Obesity
# Finish Evaluating 276 -> Reconsidering the Fed’s Inflation Forecasting Advantage
# Finish Evaluating 202 -> (Not) Everyone can be a winner — The role of payoff interdependence for redistribution
# Finish Evaluating 255 -> The Effects of Increasing the Eligibility Age for Public Pension on Individual Labor Supply: Evidence from Japan
# Finish Evaluating 219 -> Dynamic Modeling via Autoregressive Conditional GB2 for Cross-Sectional Maxima of Financial Time Series Data
# Finish Evaluating 204 -> Recession experiences during early adulthood shape prosocial attitudes later in life
# Finish Evaluating 270 -> R&D, Market Power, and the Cyclicality of Employment
# Finish Evaluating 235 -> What matters for the decision to study abroad? A lab-in-the-field experiment in Cape Verde
# Finish Evaluating 284 -> Discretion in pay ratio estimation
# Finish Evaluating 216 -> A Revealed Preference Approach to Identification and Inference in Producer-Consumer Models
# Finish Evaluating 218 -> Model Selection for Multivalued-Treatment Policy Learning in Observational Studies
# Finish Evaluating 294 -> Health, Health Insurance, and Inequality
# Finish Evaluating 246 -> Widening access in university admissions
# Finish Evaluating 213 -> Precision Least Squares: Estimation and Inference in High-Dimensions
# Finish Evaluating 234 -> Are students really biased against female professors? — Experimental evidence from India
# Finish Evaluating 205 -> Effects of restrictive abortion legislation on cohort mortality: evidence from 19th century law variation
# Finish Evaluating 209 -> Vote early and vote often? Detecting electoral fraud from the timing of 19th century elections
# Finish Evaluating 251 -> Beyond Reading, Writing, and Arithmetic: The Role of Teachers and Schools in Reporting Child Maltreatment
# Finish Evaluating 236 -> Better strategies for saving more: Evidence from three interventions in Chile
# Finish Evaluating 272 -> Government Spending, Debt Management, and Wealth and Income Inequality in a Growing Monetary Economy
# Finish Evaluating 252 -> Managing Long Working Hours: Evidence from a Management Practice Survey
# Finish Evaluating 265 -> Institutional diversity and innovative recombination
# Finish Evaluating 223 -> Multiple Structural Breaks in Interactive Effects Panel Data Models
# Finish Evaluating 229 -> Bonferroni-Type Tests for Return Predictability With Possibly Trending Predictors
# Finish Evaluating 212 -> Instability of Factor Strength in Asset Returns
# Finish Evaluating 291 -> The Unprecedented Fall in U.S. Revolving Credit
# Finish Evaluating 296 -> Constant Discounting, Temporal Instability, and Dynamic Inconsistency in Denmark: A Longitudinal Field Experiment
# Finish Evaluating 298 -> Condorcet Consistency and Pairwise Justifiability Under Variable Agendas
# Finish Evaluating 240 -> The dynamics of project standards
# Finish Evaluating 226 -> Agglomerative hierarchical clustering for selecting valid instrumental variables
# Finish Evaluating 227 -> Exploiting News Analytics for Volatility Forecasting
# Finish Evaluating 243 -> Network-based peer monitoring design
# Finish Evaluating 263 -> Market competition and the adoption of clean technology: Evidence from the taxi industry
# Finish Evaluating 221 -> Uncertainty, Skewness, and the Business Cycle Through the MIDAS Lens
# Finish Evaluating 200 -> Testing above the limit: Drinking water contamination and test scores
# Finish Evaluating 237 -> On the properties of the two main types of global poverty lines
# Finish Evaluating 286 -> How should we measure the performance of corporate bond mutual funds? Evaluating model quality and impact on inferences☆
# Finish Evaluating 242 -> Achieving safety: Personal, private, and public provision
# Finish Evaluating 254 -> Stacking the Deck for Employment Success: Labor Market Returns to Stackable Credentials
# Finish Evaluating 217 -> Estimation and Inference for a Semiparametric Time–Varying Panel Data Model
# Finish Evaluating 274 -> Identifying the Depreciation Rate of Durables from Marginal Spending Responses
# Finish Evaluating 280 -> Carbon management ability and climate risk exposure: An international investigation
# Finish Evaluating 299 -> Pensions, Income Taxes, and Homeownership: A Cross-Country Analysis
# Finish Evaluating 228 -> Nowcasting Norwegian household consumption with debit card transaction data
# Finish Evaluating 232 -> Early maternity and paternity. Effects on educational trajectories
# Finish Evaluating 275 -> Social Media Emotions and IPO Returns
# Finish Evaluating 206 -> Property taxation as compensation for local externalities: Evidence from large plants
# Finish Evaluating 244 -> Optimal discriminatory disclosure
# Finish Evaluating 266 -> Strategic parental investments in a competitive marriage market
# ...
# Evaluating 1068 -> Causality Between Brent and West Texas Intermediate: The Effects of COVID-19 Pandemic and Russia–Ukraine War
# Evaluating 1069 -> Effects of Energy Consumption, Agricultural Trade, and Productivity on Carbon Emissions in Nigeria: A Quantile Regression Approach
# Evaluating 1070 -> The effect of earnings management on profitability: Evidence from Palestine
# Evaluating 1071 -> Bank competition and access to finance by firms in the common monetary area of Southern Africa
# Evaluating 1072 -> Remittances and domestic investment in BRICS: Does financial development matter?
# Evaluating 1073 -> The spillover effects of financial system and tourism on the informal economies: Evidence from Turkey
# Evaluating 1074 -> Investigating the effect of the shadow economy on Malaysia’s economic growth: Insight from a nonlinear perspective
# Evaluating 1075 -> Stock market reaction to wrongdoing by business leaders: Empirical study in Vietnam
# Evaluating 1076 -> Effects of audit committee chair characteristics on audit quality: Empirical evidence from Saudi energy and materials sectors
# Evaluating 1077 -> Debt policy score and performance score among energy companies: Empirical evidence
# Evaluating 1078 -> Entrepreneurial networking as a mediator between entrepreneurial orientation and business performance: Insights from small business owners in Malaysia
# Evaluating 1079 -> The impact of financial inclusion on poverty in the ASEAN-8 countries
# Evaluating 1080 -> Explaining Combat Stress and its Effects on Decision Making in the Theatre of Operation
# Evaluating 1081 -> Does Modern Monetary Policy Stabilize Commodity Prices? The Paradigm During COVID-19
# Evaluating 1082 -> Machine Scheduling and Spreadsheet Modeling in a Fashion Management Class
# Evaluating 1083 -> Estimating the Size of Cash Rewards in Health Interventions: The Ex-ante Willingness to Exert Effort
# Evaluating 1084 -> The Determinants of Interest Rates in the Kingdom of Saudi Arabia: An ARDL Approach (1985-2020)
# Evaluating 1085 -> The Impact of Remittances on Exchange Rates in West African Monetary Zone (WAMZ)
# Evaluating 1086 -> Exploring Tourism Dynamics: North Macedonia in Regional Context
# Evaluating 1087 -> Expectations and Disappointments of Small and Medium-Sized Solar PV Power Plant Prosumers
# Evaluating 1088 -> Tourism Impacts on Authenticity: The Case of Old Bazaar in Skopje, North Macedonia
# Evaluating 1089 -> Pattern of Cooking Fuel Use and Household Respiratory Health in Ibadan, Nigeria
# Evaluating 1090 -> Bilateral Foreign Direct Investment between GCC Countries and Developed Economies, using a Gravity Model
# Evaluating 1091 -> Foreign Direct Investment, Institutions and Economic Growth
# Evaluating 1092 -> Macroeconomic Consequences of COVID-19 for the U.S. Economy: Implications for Fiscal Policy
# Evaluating 1093 -> The Role of GST in the Indian Automotive Sector Slowdown
# Evaluating 1094 -> Empirical Review of Food Crop Technologies Adoption in Ethiopia: Meta Analysis
# Evaluating 1095 -> The Impact of Adoption of Agricultural Production Technology in Chiro Woreda, West Harerghe, Ethiopia
# Evaluating 1096 -> Effect of Work-Life Balance on Job Satisfaction of Female Employee in Health Sector, Mogadishu, Somalia
# Evaluating 1097 -> An Exploratory Study on the Viability of Corporate Social Responsibility Practice in Ethiopian Universities: Bule Hora University
# Evaluating 1098 -> Centre Periphery Relationship: An Analysis About BRICS in Two Last Decades
# Evaluating 1099 -> The Impact of Exchange Rate Fluctuations and Money Supply on Inflation in Sierra Leone (1986-2019)
# Finish Evaluating 1090 -> Bilateral Foreign Direct Investment between GCC Countries and Developed Economies, using a Gravity Model
# Finish Evaluating 1070 -> The effect of earnings management on profitability: Evidence from Palestine
# Finish Evaluating 1022 -> Social Filter Theory—A Sleeping Beauty of Regional Innovation Theories
# Finish Evaluating 1056 -> Optimal Time Series Forecasting Through the GARMA Model
# Finish Evaluating 1000 -> Cybersecurity in Digital Accounting Systems: Challenges and Solutions in the Arab Gulf Region
# Finish Evaluating 1091 -> Foreign Direct Investment, Institutions and Economic Growth
# Finish Evaluating 1010 -> Helpless Rich Data: The Effect of Financial Openness with Dimensionality Reduction
# Finish Evaluating 1018 -> The Effect of Financial Market Capitalisation on Economic Growth and Unemployment in South Africa
# Finish Evaluating 1085 -> The Impact of Remittances on Exchange Rates in West African Monetary Zone (WAMZ)
# Finish Evaluating 1094 -> Empirical Review of Food Crop Technologies Adoption in Ethiopia: Meta Analysis
# Finish Evaluating 1014 -> Assessment of Socio-Economic Impacts of Hyperloop Technology on European Trade Routes
# Finish Evaluating 1080 -> Explaining Combat Stress and its Effects on Decision Making in the Theatre of Operation
# Finish Evaluating 1076 -> Effects of audit committee chair characteristics on audit quality: Empirical evidence from Saudi energy and materials sectors
# Finish Evaluating 1052 -> Conditional β-Convergence in APEC Economies, 1960–2020: Empirical Evidence from the Pooled Mean Group Estimator
# Finish Evaluating 1082 -> Machine Scheduling and Spreadsheet Modeling in a Fashion Management Class
# Finish Evaluating 1025 -> A Review of the Sustainability of Helium: An Assessment of Its Past, Present and a Zero-Carbon Future
# Finish Evaluating 1089 -> Pattern of Cooking Fuel Use and Household Respiratory Health in Ibadan, Nigeria
# Finish Evaluating 1017 -> Financial and Economic Determinants of Banks Financial Distress in MENA Region
# Finish Evaluating 1084 -> The Determinants of Interest Rates in the Kingdom of Saudi Arabia: An ARDL Approach (1985-2020)
# Finish Evaluating 1071 -> Bank competition and access to finance by firms in the common monetary area of Southern Africa
# Finish Evaluating 1083 -> Estimating the Size of Cash Rewards in Health Interventions: The Ex-ante Willingness to Exert Effort
# Finish Evaluating 1015 -> Technical Progress and Sustainable Growth in the Manufacturing Sector of North American Countries, 1984–2022: A Stochastic Frontier Analysis
# Finish Evaluating 1075 -> Stock market reaction to wrongdoing by business leaders: Empirical study in Vietnam
# Finish Evaluating 1065 -> Are German Automotive Suppliers in the Commodity Trap? Risks and Potentials of the Taiwanese Platform MIH EV Open
# Finish Evaluating 1028 -> Education, Science and Technology, and Talent Integrated Development: Evidence from China
# Finish Evaluating 1077 -> Debt policy score and performance score among energy companies: Empirical evidence
# Finish Evaluating 1005 -> Firm Performance and the Determinants in the Textile and Textile Product Industry of Indonesia Pre- and Post-COVID-19 Pandemic
# Finish Evaluating 1039 -> Shifting from Religious Populism to Authoritarian Populism: Two Decades of Identity Politics Dynamics in Indonesia
# Finish Evaluating 1024 -> The Digital Economy, R&D Investments, and CO2 Emissions: Unraveling Reduction Potentials in China
# Finish Evaluating 1064 -> Benefits of Property Assessed Clean Energy Programs and Securitization of Property Assessed Clean Energy Loans
# Finish Evaluating 1002 -> Private Information Production and the Efficiency of Intra-Industry Information Transfers
# Finish Evaluating 1067 -> An Econometric and Time Series Analysis of the USTC Depeg’s Impact on the LUNA Classic Price Crash During Spring 2022’s Crypto Market Turmoil
# Finish Evaluating 1069 -> Effects of Energy Consumption, Agricultural Trade, and Productivity on Carbon Emissions in Nigeria: A Quantile Regression Approach
# Finish Evaluating 1060 -> Secondhand Clothing in Global Commerce: Trade Patterns and Impact
# Finish Evaluating 1006 -> The Stability of Trend Management Strategies in Chaotic Market Conditions
# Finish Evaluating 1011 -> Public Expenditure and Economic Growth: Further Evidence for the European Union
# Finish Evaluating 1092 -> Macroeconomic Consequences of COVID-19 for the U.S. Economy: Implications for Fiscal Policy
# Finish Evaluating 1096 -> Effect of Work-Life Balance on Job Satisfaction of Female Employee in Health Sector, Mogadishu, Somalia
# Finish Evaluating 1079 -> The impact of financial inclusion on poverty in the ASEAN-8 countries
# Finish Evaluating 1036 -> “They Are Our Children”: An Examination of Faith-Based, Tuition-Free, Private Schools as Potential Sites of Educational Opportunity for Refugee Children in Egypt and Lebanon
# Finish Evaluating 1059 -> Forecasting Half-Hourly Electricity Prices Using a Mixed-Frequency Structural VAR Framework
# Finish Evaluating 1026 -> An Evaluation of the Rural Tourism Industry’s Competitiveness in the Yangtze River Economic Belt Based on the “Diamond Model”—Exampled by Wenjiang District, Huangpi District, and Jiangning District
# Finish Evaluating 1020 -> Spatial Pattern Evolution and Influencing Factors of Foreign Star-Rated Hotels in Chinese Cities
# Finish Evaluating 1042 -> Strategic Impacts of RSUs on Company Performance: Insights into EPS and Profitability Growth
# Finish Evaluating 1032 -> The Role of Lithuanian Heritage Language Schools in Cultural Identity and Language Learning: Perceptions of Parents and Teachers
# Finish Evaluating 1031 -> Examining Trauma-Related Shame and Trauma Coping Self-Efficacy as Predictors of PTSD in Women in Jail
# Finish Evaluating 1009 -> Risk Management in DeFi: Analyses of the Innovative Tools and Platforms for Tracking DeFi Transactions
# Finish Evaluating 1058 -> Comparative Analysis of VAR and SVAR Models in Assessing Oil Price Shocks and Exchange Rate Transmission to Consumer Prices in South Africa
# Finish Evaluating 1007 -> Examining Market Quality on the Egyptian Exchange (EGX): An Intraday Liquidity Analysis
# Finish Evaluating 1057 -> Investigating Some Issues Relating to Regime Matching
# Finish Evaluating 1019 -> The Effects of Foreign Direct Investments on Wage Trends in the Dutch Labor Market
# Finish Evaluating 1013 -> Unboxing Okun’s Relation Between Economic Growth and Unemployment Rate: Evidence from the United States, 1948–2024
# Finish Evaluating 1072 -> Remittances and domestic investment in BRICS: Does financial development matter?
# Finish Evaluating 1099 -> The Impact of Exchange Rate Fluctuations and Money Supply on Inflation in Sierra Leone (1986-2019)
# Finish Evaluating 1030 -> Casilda Iturrizar: A Case of Overcoming the Invisibilization of Women Relevant for Their Religiosity
# Finish Evaluating 1043 -> Uncertainty, Risk, and Opaque Stock Markets
# Finish Evaluating 1053 -> Application of Fuzzy Discount Factors in Behavioural Decision-Making for Financial Market Modelling
# Finish Evaluating 1037 -> Navigating New Beginnings: A Study of State-Level Grant Funding Support for K-12 Refugee Education
# Finish Evaluating 1023 -> Clustering of Basic Educational Resources and Urban Resilience Development in the Central Region of China—An Empirical Study Based on POI Data
# Finish Evaluating 1003 -> Assessing Basel Capital Regulations: Exploring the Risk and Efficiency Relationship in Emerging Economies
# Finish Evaluating 1086 -> Exploring Tourism Dynamics: North Macedonia in Regional Context
# Finish Evaluating 1088 -> Tourism Impacts on Authenticity: The Case of Old Bazaar in Skopje, North Macedonia
# Finish Evaluating 1033 -> Podcasting as an Innovative Pedagogical Tool in Social Work Education
# Finish Evaluating 1054 -> A Study of Economic and Social Preferences in Energy-Saving Behavior Using a Structural Equation Modeling Approach: The Case of Romania
# Finish Evaluating 1051 -> Data-Based Parametrization for Affine GARCH Models Across Multiple Time Scales—Roughness Implications
# Finish Evaluating 1049 -> Economic Growth in Rural Areas, Resource Agglomeration, and Stock Market Performance: Evidence from China
# Finish Evaluating 1068 -> Causality Between Brent and West Texas Intermediate: The Effects of COVID-19 Pandemic and Russia–Ukraine War
# Finish Evaluating 1035 -> Not All Migrants Are the Same: Decent Work and Pre- and Post-Migration Experiences of Economic Migrants
# Finish Evaluating 1061 -> Time-Varying Deterministic Volatility Model for Options on Wheat Futures
# Finish Evaluating 1034 -> Welfare Conditionality and Social Identity Effect Mechanisms and the Case of Immigrant Support
# Finish Evaluating 1095 -> The Impact of Adoption of Agricultural Production Technology in Chiro Woreda, West Harerghe, Ethiopia
# Finish Evaluating 1073 -> The spillover effects of financial system and tourism on the informal economies: Evidence from Turkey
# Finish Evaluating 1055 -> An Economic Theory with a Formal-Econometric Test of Its Empirical Relevance
# Finish Evaluating 1016 -> How the Tourism Industry Can Help Resolve Mongolia’s Environmental Problems
# Finish Evaluating 1041 -> AI in Banking: What Drives Generation Z to Adopt AI-Enabled Voice Assistants in Saudi Arabia?
# Finish Evaluating 1081 -> Does Modern Monetary Policy Stabilize Commodity Prices? The Paradigm During COVID-19
# Finish Evaluating 1078 -> Entrepreneurial networking as a mediator between entrepreneurial orientation and business performance: Insights from small business owners in Malaysia
# Finish Evaluating 1001 -> The Impact of Board of Directors’ Characteristics on the Financial Performance of the Banking Sector in Gulf Cooperation Council (GCC) Countries: The Moderating Role of Bank Size
# Finish Evaluating 1047 -> How Foreign and Domestic Ownership Influenced Risk-Taking in GCC Banks
# Finish Evaluating 1008 -> Beyond the Buzz: A Measured Look at Bitcoin’s Viability as Money
# Finish Evaluating 1097 -> An Exploratory Study on the Viability of Corporate Social Responsibility Practice in Ethiopian Universities: Bule Hora University
# Finish Evaluating 1027 -> Evolution and Drivers of Embodied Energy in Intermediate and Final Fishery Trade Between China and Maritime Silk Road Countries
# Finish Evaluating 1004 -> The Donkey and the Thorn Tree: Reappraising Globalisation and Africa
# Finish Evaluating 1048 -> Towards Economic Sustainability: A Comprehensive Review of Artificial Intelligence and Machine Learning Techniques in Improving the Accuracy of Stock Market Movements
# Finish Evaluating 1045 -> Digital Transformation and the Quality of Accounting Information Systems in the Public Sector: Evidence from Developing Countries
# Finish Evaluating 1074 -> Investigating the effect of the shadow economy on Malaysia’s economic growth: Insight from a nonlinear perspective
# Finish Evaluating 1038 -> Practices in Integrating Workplace Learning into Upper Secondary Education
# Finish Evaluating 1063 -> Commodity Prices and the Brazilian Stock Market: Evidence from a Structural VAR Model
# Finish Evaluating 1066 -> Performance of Commodity Futures-Based Dynamic Portfolios
# Finish Evaluating 1062 -> Econometric Insights into LNG Carrier Port Congestion and Energy Inflation: A Data-Driven Approach
# Finish Evaluating 1046 -> Navigating Uncertainty in an Emerging Market: Data-Centric Portfolio Strategies and Systemic Risk Assessment in the Johannesburg Stock Exchange
# Finish Evaluating 1021 -> Research on the Role of Digital Finance in Urban Green Innovation
# Finish Evaluating 1087 -> Expectations and Disappointments of Small and Medium-Sized Solar PV Power Plant Prosumers
# Finish Evaluating 1029 -> Economic and Geographical Impact of Development Poles: Industrial and Commercial Transformations of the Forestry Sector in Gabon
# Finish Evaluating 1012 -> Place-Based Approach to Rural Development: Ethiopia in Context
# Finish Evaluating 1040 -> Cryptocurrency Taxation: A Bibliometric Analysis and Emerging Trends
# Finish Evaluating 1098 -> Centre Periphery Relationship: An Analysis About BRICS in Two Last Decades
# Finish Evaluating 1050 -> Relationship Between Coefficients in Parametric Survival Models for Exponentially Distributed Survival Time—Registered Unemployment in Poland
# Finish Evaluating 1044 -> A Real Option Approach to the Valuation of the Default Risk of Residential Mortgages
# Finish Evaluating 1093 -> The Role of GST in the Indian Automotive Sector Slowdown

# %%
# # Fallback
# fallback = df[df.isna().any(axis=1)].index

# with ThreadPoolExecutor(max_workers=200) as executor:
#         results = list(executor.map(
#             evaluate_paper, 
#             [client] * len(fallback),
#             fallback,
#             [df] * len(fallback),
#         ))
        
# df.to_csv(f"{model_name}/fallback.csv", index=False)

# %%
full = pd.read_csv("dump/csv/result_oalg.csv")

# %%
cols = [ 'gemma-score-1',
 'gemma-score-2',
 'gemma-score-3',
 'gemma-originality-1',
 'gemma-rigor-1',
 'gemma-scope-1',
 'gemma-impact-1',
 'gemma-written_by_ai-1',
 'gemma-originality-2',
 'gemma-rigor-2',
 'gemma-scope-2',
 'gemma-impact-2',
 'gemma-written_by_ai-2',
 'gemma-originality-3',
 'gemma-rigor-3',
 'gemma-scope-3',
 'gemma-impact-3',
 'gemma-written_by_ai-3',]

for col in cols:
    # copy column from full to df
    df[col.split("-")[0] + "-100-" + "-".join(col.split("-")[1:])] = full[col]

# %%
df.to_csv('gemma-partial.csv')
